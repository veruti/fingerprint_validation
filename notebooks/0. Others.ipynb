# %% [markdown]
# # Function for getting findContours results

# %%
import sys

sys.path.insert(0, '..')

# %%
import cv2 as cv
from src.preparation.reading import *
from src.processing.standardization import *
import matplotlib.pyplot as plt

# %%
im = read_random_image(RAW_FILE_PATH_GOODIM)
plt.imshow(im, plt.cm.gray)

# %%
inv_im = invers_color(im)

plt.imshow(inv_im, plt.cm.gray)
plt.show()

# %% [markdown]
# ## Make function for getting results

# %%
def findContoursResult(res):
    if len(res) == 2:
        return res[0], res[1]
    elif len(res) == 3:
        return res[1], res[2]
    else:
        return None

# %%
res = cv.findContours(inv_im, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
contours, hierarchy = findContoursResult(res)
