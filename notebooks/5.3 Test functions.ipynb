# %% [markdown]
# # Matplotlib and pylab inline

# %%
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Import libraries

# %%
import os
import cv2 as cv
import matplotlib.pyplot as plt

from matplotlib import rcParams
from modules.reading import *
from modules.standardization import standardize_image
from modules.preprocessing import preproc_image
from modules.noise import get_scalar_product_precentiles, get_all_pair_sp_percentiles


rcParams["figure.dpi"] = 100
rcParams["figure.figsize"] = (4, 5)
rcParams["image.cmap"] = "gray"

# %% [markdown]
# # Test scalar product

# %%
im = read_random_image(RAW_FILE_PATH_GOODIM)
std_im = standardize_image(im)
prep_im = preproc_image(std_im)

plt.imshow(prep_im)
plt.show()

# %%
# %%timeit
get_scalar_product_precentiles(prep_im)
# Out:
# 43.8 ms ± 6.99 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
get_all_pair_sp_percentiles(prep_im)
# Out:
# 276 ms ± 3.85 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # It works
