# %% [markdown]
# # Matplotlib and pylab inline

# %%
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Add path .. to make relative import

# %%
import sys

sys.path.insert(0, '..')

# %% [markdown]
# # Import libraries

# %%
import os
import cv2 as cv
import matplotlib.pyplot as plt

from matplotlib import rcParams
from src.preparation.reading import *
from src.processing.standardization import standardize_image
from src.processing.preprocessing import preproc_image
from src.processing.noise import get_scalar_product_precentiles, get_all_pair_sp_percentiles


rcParams["figure.dpi"] = 100
rcParams["figure.figsize"] = (4, 5)
rcParams["image.cmap"] = "gray"

# %% [markdown]
# # Test scalar product

# %%
im = read_random_image(RAW_FILE_PATH_GOODIM)
std_im = standardize_image(im)
prep_im = preproc_image(std_im)

plt.imshow(prep_im)
plt.show()

# %%
# %%timeit
get_scalar_product_precentiles(prep_im)
# Out:
# 19.7 ms ± 129 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
get_all_pair_sp_percentiles(prep_im)
# Out:
# 170 ms ± 1.52 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # It works
