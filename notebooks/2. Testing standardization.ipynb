# %% [markdown]
# # Matplotlib and pylab inline

# %%
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Import libraries

# %%
import cv2 as cv
from modules.reading import *
import matplotlib.pyplot as plt
from matplotlib import rcParams

rcParams["figure.dpi"] = 100
rcParams["figure.figsize"] = (4, 5)
rcParams["image.cmap"] = "gray"

# %% [markdown]
# # Testing read function

# %%
im = read_random_image(RAW_FILE_PATH_GOODIM)

plt.imshow(im)
pass

# %% [markdown]
# # Import standardization function

# %%
from modules.standardization import *

# %% [markdown]
# ## Test inverse color function

# %%
im = read_random_image(RAW_FILE_PATH_BADIM_HOLES)
inv_im = invers_color(im)

plt.imshow(inv_im)
pass

# %%
# %prun invers_color(im)
# Out:
#          15 function calls in 0.001 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001    0.001    0.001 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 {bitwise_not}
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
#         1    0.000    0.000    0.001    0.001 _methods.py:134(_mean)
#         1    0.000    0.000    0.001    0.001 standardization.py:5(invers_color)
#         1    0.000    0.000    0.000    0.000 _methods.py:50(_count_reduce_items)
#         1    0.000    0.000    0.001    0.001 {method 'mean' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.001    0.001 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.000    0.000 _asarray.py:88(asanyarray)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# # Test crop imgae function

# %%
im = read_random_image(RAW_FILE_PATH_GOODIM)
inv_im = invers_color(im)

plt.imshow(inv_im)
plt.show()

crop_im = crop_fp_image(inv_im)

plt.imshow(crop_im)
plt.show()

# %%
# %prun crop_fp_image(inv_im)
# Out:
#          99 function calls (97 primitive calls) in 0.002 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.002    0.002    0.002    0.002 {findContours}
#         1    0.000    0.000    0.002    0.002 {built-in method builtins.exec}
#       3/1    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         1    0.000    0.000    0.000    0.000 {copyMakeBorder}
#         1    0.000    0.000    0.000    0.000 standardization.py:38(get_golden_ratio_image)
#         1    0.000    0.000    0.002    0.002 standardization.py:51(crop_fp_image)
#         1    0.000    0.000    0.000    0.000 shape_base.py:82(atleast_2d)
#         1    0.000    0.000    0.000    0.000 shape_base.py:223(vstack)
#         1    0.000    0.000    0.002    0.002 <string>:1(<module>)
#        24    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         1    0.000    0.000    0.000    0.000 other.py:3(find_contours_result)
#         1    0.000    0.000    0.000    0.000 {boundingRect}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(vstack)
#        24    0.000    0.000    0.000    0.000 _asarray.py:88(asanyarray)
#        24    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 standardization.py:24(get_proportion)
#         1    0.000    0.000    0.000    0.000 shape_base.py:78(_atleast_2d_dispatcher)
#         1    0.000    0.000    0.000    0.000 shape_base.py:208(_arrays_for_stack_dispatcher)
#         1    0.000    0.000    0.000    0.000 shape_base.py:219(_vhstack_dispatcher)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_2d)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(concatenate)
#         1    0.000    0.000    0.000    0.000 multiarray.py:145(concatenate)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}

# %% [markdown]
# # Test resize function

# %%
# %%timeit
im = read_random_image(RAW_FILE_PATH_GOODIM)

inv_im = invers_color(im)
#plt.imshow(inv_im)
#plt.show()

crop_im = crop_fp_image(inv_im)
#plt.imshow(crop_im)
#plt.show()

resized_im = resize_fp_image(crop_im)
#plt.imshow(resized_im)
#print(resized_im.shape)
#plt.show()
# Out:
# 5.24 ms ± 234 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %prun resize_fp_image(crop_im)
# Out:
#          5 function calls in 0.000 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 {resize}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 standardization.py:105(resize_fp_image)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# # Test unite function

# %%
im = read_random_image(RAW_FILE_PATH_GOODIM)
fp_im = standardize_image(im)

plt.imshow(fp_im)
plt.show()

# %%
# %prun standardize_image(im)
# Out:
#          81 function calls (79 primitive calls) in 0.001 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 {findContours}
#         1    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 {resize}
#         1    0.000    0.000    0.000    0.000 {bitwise_not}
#         1    0.000    0.000    0.000    0.000 _methods.py:134(_mean)
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
#       3/1    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         1    0.000    0.000    0.000    0.000 standardization.py:51(crop_fp_image)
#         1    0.000    0.000    0.000    0.000 standardization.py:38(get_golden_ratio_image)
#         1    0.000    0.000    0.000    0.000 {copyMakeBorder}
#         1    0.000    0.000    0.000    0.000 standardization.py:5(invers_color)
#         1    0.000    0.000    0.000    0.000 shape_base.py:82(atleast_2d)
#        14    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         1    0.000    0.000    0.000    0.000 _methods.py:50(_count_reduce_items)
#         1    0.000    0.000    0.001    0.001 standardization.py:126(standardize_image)
#         1    0.000    0.000    0.000    0.000 shape_base.py:223(vstack)
#        14    0.000    0.000    0.000    0.000 _asarray.py:88(asanyarray)
#         1    0.000    0.000    0.000    0.000 standardization.py:105(resize_fp_image)
#         1    0.000    0.000    0.000    0.000 {boundingRect}
#         1    0.000    0.000    0.001    0.001 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(vstack)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {method 'mean' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        13    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 other.py:3(find_contours_result)
#         1    0.000    0.000    0.000    0.000 standardization.py:24(get_proportion)
#         1    0.000    0.000    0.000    0.000 shape_base.py:219(_vhstack_dispatcher)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_2d)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(concatenate)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 shape_base.py:78(_atleast_2d_dispatcher)
#         1    0.000    0.000    0.000    0.000 shape_base.py:208(_arrays_for_stack_dispatcher)
#         1    0.000    0.000    0.000    0.000 multiarray.py:145(concatenate)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
